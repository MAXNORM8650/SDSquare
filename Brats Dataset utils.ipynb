# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\Admin\Dropbox\PC\Documents\Anomaly Detection\AnoDDPM\DATASETS\brats2021"

# %%
mask_path = os.path.join(path, "Mask.txt")
anno_path = os.path.join(path, "Anomaly.txt")

# %%
mask_files = [i for i in open(mask_path, "r")]
anno_files = [i for i in open(anno_path, "r")]

# %%
load_path = os.path.join(path, "traning_data")

# %%
l = []
for i in range(len(mask_files)):
    img_numpy_path = os.path.join(load_path, anno_files[i])[:-1]
    os.remove(img_numpy_path)
#     print(img_numpy_path)
#     image = np.load(img_numpy_path)
    mask_numpy_path = os.path.join(load_path, mask_files[i])[:-1]
    os.remove(mask_numpy_path)
#     mask = np.load(mask_numpy_path)
#     l.append([np.mean(image), np.mean(mask)])

# %%
plt.imshow(image)

# %%
m = r"C:\Users\Admin\Dropbox\PC\Documents\Anomaly Detection\AnoDDPM\DATASETS\brats2021\traning_data\BraTS2021_00003\BraTS2021_00003_Mask_1.npy"
ms = np.load(m)

# %%
plt.imshow(ms)

# %%
plt.imshow(mask)
