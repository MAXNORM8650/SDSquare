# %%
import argparse
import os

import blobfile as bf
import torch as th
import torch
import torch.distributed as dist
import torch.nn.functional as F
from torch.nn.parallel.distributed import DistributedDataParallel as DDP
from torch.optim import AdamW

from guided_diffusion import dist_util, logger
from guided_diffusion.fp16_util import MixedPrecisionTrainer
from guided_diffusion.image_datasets import load_data
from guided_diffusion.resample import create_named_schedule_sampler
from guided_diffusion.script_util import (
    add_dict_to_argparser,
    args_to_dict,
    classifier_and_diffusion_defaults,
    create_classifier_and_diffusion,
)
from guided_diffusion.train_util import parse_resume_step_from_filename, log_loss_dict

# %%
import collections
import copy
import sys
import time
from random import seed

import matplotlib.pyplot as plt
import numpy as np
from matplotlib import animation
from torch import optim
from guided_diffusion.fp16_util import MixedPrecisionTrainer
import dataset
import evaluation
from GaussianDiffusion import GaussianDiffusionModel, get_beta_schedule
from helpers import *
from UNet import UNetModel, update_ema_params
from script_util import (
    add_dict_to_argparser,
    args_to_dict,
    classifier_and_diffusion_defaults,
    create_classifier_and_diffusion,
)
torch.cuda.empty_cache()

# from train_util import  log_loss_dict

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
args_dict = {
  "image_size": 256,
  "Batch_Size": 16,
  "batch_size": 16,
  "channels": 3,
  "EPOCHS": 4000,
  "iterations":40000,
  "diffusion_steps": 1000,
  "num_channels": 192,\
  "learn_sigma":True,
  "val_data": True,
  "eval_interval": 1000,
  "save_interval": 1000,
  "log_interval": 10,
  "anneal_lr": True,
  "microbatch": -1,
  "use_kl":False,
  "schedule_sampler": "uniform",
  "resume_checkpoint": False,
  "predict_xstart":False,
  "rescale_timesteps":False,
  "rescale_learned_sigmas":False,
  "timestep_respacing": "",
  "noise_schedule": "cosine",
  "channel_mults": "",
  "loss-type": "l2",
  "loss_weight": "none",
  "train_start": True,
  "lr": 1e-4,
  "learn_sigma ": True,
  "random_slice": True,
  "sample_distance": 800,
  "weight_decay": 0.0,
  "save_imgs": True,
  "save_vids": True,
  "class_cond ": True,
  "use_fp16": True,
  "use_scale_shift_norm": True,
  "dropout": 0.1,
  "attention_resolutions": "32,16,8",
  "num_res_blocks": 3,
  "resblock_updown": True,
  "classifier_use_fp16":False,
  "classifier_width":128,
  "classifier_depth": 2,
  "classifier_attention_resolutions": "32,16,8",
  "classifier_use_scale_shift_norm": True,
  "classifier_resblock_updown": True,
  "classifier_pool": "attention" ,
  "num_head_channels": 64,
  "noised": True,
  "noise_fn": "gauss",
  "dataset": "mura"
}

# %%
args = argparse.Namespace(**args_dict)

# %%
# args.

# %%
from tqdm import tqdm

# %%
ROOT_DIR= './'

# %%
def main():
#     args = create_argparser().parse_args()

#     dist_util.setup_dist()
    logger.configure()

    logger.log("creating model and diffusion...")
    model, diffusion = create_classifier_and_diffusion(args_dict
    )
    model.to(device)
    if args.noised:
        schedule_sampler = create_named_schedule_sampler(
            args.schedule_sampler, diffusion
        )

    resume_step = 0
    if args.resume_checkpoint:
        resume_step = parse_resume_step_from_filename(args.resume_checkpoint)
#         if dist.get_rank() == 0:
        logger.log(
            f"loading model from checkpoint: {args.resume_checkpoint}... at {resume_step} step"
        )
        model.load_state_dict(
            dist_util.load_state_dict(
                args.resume_checkpoint, map_location=device
            )
        )

    # Needed for creating correct EMAs and fp16 parameters.
#     dist_util.sync_params(model.parameters())

    mp_trainer = MixedPrecisionTrainer(
        model=model, use_fp16=args.classifier_use_fp16, initial_lg_loss_scale=16.0
    )

#     model = DDP(
#         model,
#         device_ids=[dist_util.dev()],
#         output_device=device(),
#         broadcast_buffers=False,
#         bucket_cap_mb=128,
#         find_unused_parameters=False,
#     )

    logger.log("creating data loader...")
    training_dataset, testing_dataset = dataset.init_datasets(ROOT_DIR, args_dict)
    data = dataset.init_dataset_loader(training_dataset, args_dict)
    if args.val_data:
        val_data = dataset.init_dataset_loader(testing_dataset, args_dict)
    else:
        val_data = None

    logger.log(f"creating optimizer...")
    opt = AdamW(mp_trainer.master_params, lr=args.lr, weight_decay=args.weight_decay)
    if args.resume_checkpoint:
        opt_checkpoint = bf.join(
            bf.dirname(args.resume_checkpoint), f"opt{resume_step:06}.pt"
        )
        logger.log(f"loading optimizer state from checkpoint: {opt_checkpoint}")
        opt.load_state_dict(
            dist_util.load_state_dict(opt_checkpoint, map_location=device)
        )

    logger.log("training classifier model...")

    def forward_backward_log(data_loader, prefix="train"):
        extra = next(data_loader)
        batch = extra["image"]
        labels = extra["label"].to(device)

        batch = batch        extra = next(data_loader)
        batch = extra["image"]
        labels = extra["label"].to(device)

        # Noisy images
        if args.noised:
            t, _ = schedule_sampler.sample(batch.shape[0], device)
            batch = diffusion.q_sample(batch, t)
        else:
            t = th.zeros(batch.shape[0], dtype=th.long, device=device)

        for i, (sub_batch, sub_labels, sub_t) in enumerate(
            split_microbatches(args.microbatch, batch, labels, t)
        ):
            logits = model(sub_batch, timesteps=sub_t)
            loss = F.cross_entropy(logits, sub_labels, reduction="none")

            losses = {}
            losses[f"{prefix}_loss"] = loss.detach()
            losses[f"{prefix}_acc@1"] = compute_top_k(
                logits, sub_labels, k=1, reduction="none"
            )
            losses[f"{prefix}_acc@5"] = compute_top_k(
                logits, sub_labels, k=5, reduction="none"
            )
            log_loss_dict(diffusion, sub_t, losses)
            del losses
            loss = loss.mean()
            if loss.requires_grad:
                if i == 0:
                    mp_trainer.zero_grad()
                mp_trainer.backward(loss * len(sub_batch) / len(batch))

    for step in tqdm(range(args.iterations - resume_step)):
        logger.logkv("step", step + resume_step)
        logger.logkv(
            "samples",
            (step + resume_step + 1) * args.batch_size,
        )
        if args.anneal_lr:
            set_annealed_lr(opt, args.lr, (step + resume_step) / args.iterations)
        forward_backward_log(data)
        mp_trainer.optimize(opt)
        if val_data is not None and not step % args.eval_interval:
            with th.no_grad():
                model.eval()
                forward_backward_log(val_data, prefix="val")
                model.train()
        if not step % args.log_interval:
            logger.dumpkvs()
        if (step + resume_step) % args.save_interval:
            logger.log("saving model...")
            save_model(mp_trainer, opt, step + resume_step)

#     if dist.get_rank() == 0:
    logger.log("saving model...")
    save_model(mp_trainer, opt, step + resume_step)
#     dist.barrier()


def set_annealed_lr(opt, base_lr, frac_done):
    lr = base_lr * (1 - frac_done)
    for param_group in opt.param_groups:
        param_group["lr"] = lr


def save_model(mp_trainer, opt, step):
    th.save(
        mp_trainer.master_params_to_state_dict(mp_trainer.master_params),
        os.path.join(logger.get_dir(), f"model{step:06d}.pt"),
    )
    th.save(opt.state_dict(), os.path.join(logger.get_dir(), f"opt{step:06d}.pt"))


def compute_top_k(logits, labels, k, reduction="mean"):
    _, top_ks = th.topk(logits, k, dim=-1)
    if reduction == "mean":
        return (top_ks == labels[:, None]).float().sum(dim=-1).mean().item()
    elif reduction == "none":
        return (top_ks == labels[:, None]).float().sum(dim=-1)


def split_microbatches(microbatch, *args):
    bs = len(args[0])
    if microbatch == -1 or microbatch >= bs:
        yield tuple(args)
    else:
        for i in range(0, bs, microbatch):
            yield tuple(x[i : i + microbatch] if x is not None else None for x in args)


def create_argparser():
    defaults = dict(
        data_dir="",
        val_data_dir="",
        noised=True,
        iterations=150000,
        lr=3e-4,
        weight_decay=0.0,
        anneal_lr=False,
        batch_size=4,
        microbatch=-1,
        schedule_sampler="uniform",
        resume_checkpoint="",
        log_interval=10,
        eval_interval=5,
        save_interval=10000,
    )
    defaults.update(classifier_and_diffusion_defaults())
    parser = argparse.ArgumentParser()
    add_dict_to_argparser(parser, defaults)
    return parser


if __name__ == "__main__":
    main()
# Out:
# Logging to C:\Users\Admin\AppData\Local\Temp\openai-2023-02-15-20-57-48-717999
# creating model and diffusion...
# creating data loader...
# creating optimizer...
# training classifier model...
# C:\Users\Admin\anaconda3\envs\en_2\lib\site-packages\torchvision\transforms\transforms.py:329: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# -----------------------------
# | grad_norm      | 145      |
# | param_norm     | 160      |
# | samples        | 16       |
# | step           | 0        |
# | train_acc@1    | 0        |
# | train_acc@1_q0 | 0        |
# | train_acc@1_q1 | 0        |
# | train_acc@1_q2 | 0        |
# | train_acc@1_q3 | 0        |
# | train_acc@5    | 0        |
# | train_acc@5_q0 | 0        |
# | train_acc@5_q1 | 0        |
# | train_acc@5_q2 | 0        |
# | train_acc@5_q3 | 0        |
# | train_loss     | 6.78     |
# | train_loss_q0  | 6.75     |
# | train_loss_q1  | 6.77     |
# | train_loss_q2  | 6.79     |
# | train_loss_q3  | 6.84     |
# | val_acc@1      | 0.562    |
# | val_acc@1_q0   | 0.75     |
# | val_acc@1_q1   | 1        |
# | val_acc@1_q2   | 0.2      |
# | val_acc@1_q3   | 0.5      |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 4.89     |
# | val_loss_q0    | 4.65     |
# | val_loss_q1    | 4.23     |
# | val_loss_q2    | 5.4      |
# | val_loss_q3    | 4.97     |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 12.4     |
# | param_norm     | 160      |
# | samples        | 176      |
# | step           | 10       |
# | train_acc@1    | 0.65     |
# | train_acc@1_q0 | 0.625    |
# | train_acc@1_q1 | 0.684    |
# | train_acc@1_q2 | 0.743    |
# | train_acc@1_q3 | 0.574    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 3.18     |
# | train_loss_q0  | 3.36     |
# | train_loss_q1  | 3.05     |
# | train_loss_q2  | 2.96     |
# | train_loss_q3  | 3.32     |
# | val_acc@1      | 0.438    |
# | val_acc@1_q0   | 0.286    |
# | val_acc@1_q1   | 0.6      |
# | val_acc@1_q2   | 0.417    |
# | val_acc@1_q3   | 0.5      |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 2.94     |
# | val_loss_q0    | 3.38     |
# | val_loss_q1    | 2.26     |
# | val_loss_q2    | 3.07     |
# | val_loss_q3    | 2.8      |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 9.73     |
# | param_norm     | 160      |
# | samples        | 336      |
# | step           | 20       |
# | train_acc@1    | 0.594    |
# | train_acc@1_q0 | 0.514    |
# | train_acc@1_q1 | 0.611    |
# | train_acc@1_q2 | 0.619    |
# | train_acc@1_q3 | 0.622    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 1.31     |
# | train_loss_q0  | 1.53     |
# | train_loss_q1  | 1.21     |
# | train_loss_q2  | 1.18     |
# | train_loss_q3  | 1.33     |
# | val_acc@1      | 0.625    |
# | val_acc@1_q0   | 0.714    |
# | val_acc@1_q1   | 0.556    |
# | val_acc@1_q2   | 0.667    |
# | val_acc@1_q3   | 0.571    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.794    |
# | val_loss_q0    | 0.647    |
# | val_loss_q1    | 0.891    |
# | val_loss_q2    | 0.743    |
# | val_loss_q3    | 0.881    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 12.9     |
# | param_norm     | 160      |
# | samples        | 496      |
# | step           | 30       |
# | train_acc@1    | 0.494    |
# | train_acc@1_q0 | 0.617    |
# | train_acc@1_q1 | 0.462    |
# | train_acc@1_q2 | 0.371    |
# | train_acc@1_q3 | 0.487    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.811    |
# | train_loss_q0  | 0.707    |
# | train_loss_q1  | 0.89     |
# | train_loss_q2  | 0.877    |
# | train_loss_q3  | 0.798    |
# | val_acc@1      | 0.375    |
# | val_acc@1_q0   | 0.333    |
# | val_acc@1_q1   | 0.4      |
# | val_acc@1_q2   | 0.3      |
# | val_acc@1_q3   | 0.5      |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.821    |
# | val_loss_q0    | 0.838    |
# | val_loss_q1    | 0.848    |
# | val_loss_q2    | 0.843    |
# | val_loss_q3    | 0.758    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 6.52     |
# | param_norm     | 160      |
# | samples        | 656      |
# | step           | 40       |
# | train_acc@1    | 0.525    |
# | train_acc@1_q0 | 0.529    |
# | train_acc@1_q1 | 0.5      |
# | train_acc@1_q2 | 0.528    |
# | train_acc@1_q3 | 0.552    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.683    |
# | train_loss_q0  | 0.669    |
# | train_loss_q1  | 0.681    |
# | train_loss_q2  | 0.684    |
# | train_loss_q3  | 0.698    |
# | val_acc@1      | 0.375    |
# | val_acc@1_q0   | 0.4      |
# | val_acc@1_q1   | 0.375    |
# | val_acc@1_q2   | 0.6      |
# | val_acc@1_q3   | 0.111    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.732    |
# | val_loss_q0    | 0.901    |
# | val_loss_q1    | 0.629    |
# | val_loss_q2    | 0.565    |
# | val_loss_q3    | 0.917    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 7.84     |
# | param_norm     | 160      |
# | samples        | 816      |
# | step           | 50       |
# | train_acc@1    | 0.525    |
# | train_acc@1_q0 | 0.385    |
# | train_acc@1_q1 | 0.639    |
# | train_acc@1_q2 | 0.5      |
# | train_acc@1_q3 | 0.581    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.737    |
# | train_loss_q0  | 0.812    |
# | train_loss_q1  | 0.649    |
# | train_loss_q2  | 0.793    |
# | train_loss_q3  | 0.688    |
# | val_acc@1      | 0.5      |
# | val_acc@1_q0   | 0.364    |
# | val_acc@1_q1   | 0.5      |
# | val_acc@1_q2   | 0.8      |
# | val_acc@1_q3   | 0.2      |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.746    |
# | val_loss_q0    | 0.791    |
# | val_loss_q1    | 0.78     |
# | val_loss_q2    | 0.598    |
# | val_loss_q3    | 0.902    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 6.62     |
# | param_norm     | 160      |
# | samples        | 976      |
# | step           | 60       |
# | train_acc@1    | 0.562    |
# | train_acc@1_q0 | 0.528    |
# | train_acc@1_q1 | 0.667    |
# | train_acc@1_q2 | 0.457    |
# | train_acc@1_q3 | 0.619    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.681    |
# | train_loss_q0  | 0.736    |
# | train_loss_q1  | 0.615    |
# | train_loss_q2  | 0.739    |
# | train_loss_q3  | 0.626    |
# | val_acc@1      | 0.469    |
# | val_acc@1_q0   | 0.375    |
# | val_acc@1_q1   | 0.571    |
# | val_acc@1_q2   | 0.444    |
# | val_acc@1_q3   | 0.5      |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.839    |
# | val_loss_q0    | 0.961    |
# | val_loss_q1    | 0.771    |
# | val_loss_q2    | 0.765    |
# | val_loss_q3    | 0.86     |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 6.92     |
# | param_norm     | 160      |
# | samples        | 1.14e+03 |
# | step           | 70       |
# | train_acc@1    | 0.613    |
# | train_acc@1_q0 | 0.667    |
# | train_acc@1_q1 | 0.556    |
# | train_acc@1_q2 | 0.571    |
# | train_acc@1_q3 | 0.647    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.707    |
# | train_loss_q0  | 0.666    |
# | train_loss_q1  | 0.763    |
# | train_loss_q2  | 0.738    |
# | train_loss_q3  | 0.669    |
# | val_acc@1      | 0.531    |
# | val_acc@1_q0   | 0.5      |
# | val_acc@1_q1   | 0.455    |
# | val_acc@1_q2   | 0.455    |
# | val_acc@1_q3   | 1        |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.702    |
# | val_loss_q0    | 0.729    |
# | val_loss_q1    | 0.682    |
# | val_loss_q2    | 0.777    |
# | val_loss_q3    | 0.511    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 4.01     |
# | param_norm     | 160      |
# | samples        | 1.3e+03  |
# | step           | 80       |
# | train_acc@1    | 0.625    |
# | train_acc@1_q0 | 0.479    |
# | train_acc@1_q1 | 0.75     |
# | train_acc@1_q2 | 0.674    |
# | train_acc@1_q3 | 0.649    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.671    |
# | train_loss_q0  | 0.75     |
# | train_loss_q1  | 0.602    |
# | train_loss_q2  | 0.63     |
# | train_loss_q3  | 0.674    |
# | val_acc@1      | 0.5      |
# | val_acc@1_q0   | 0.5      |
# | val_acc@1_q1   | 0.2      |
# | val_acc@1_q2   | 0.625    |
# | val_acc@1_q3   | 0.556    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.746    |
# | val_loss_q0    | 0.727    |
# | val_loss_q1    | 0.922    |
# | val_loss_q2    | 0.687    |
# | val_loss_q3    | 0.722    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 3.4      |
# | param_norm     | 160      |
# | samples        | 1.46e+03 |
# | step           | 90       |
# | train_acc@1    | 0.613    |
# | train_acc@1_q0 | 0.587    |
# | train_acc@1_q1 | 0.676    |
# | train_acc@1_q2 | 0.667    |
# | train_acc@1_q3 | 0.545    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.67     |
# | train_loss_q0  | 0.678    |
# | train_loss_q1  | 0.621    |
# | train_loss_q2  | 0.67     |
# | train_loss_q3  | 0.699    |
# | val_acc@1      | 0.531    |
# | val_acc@1_q0   | 0.6      |
# | val_acc@1_q1   | 0.5      |
# | val_acc@1_q2   | 0.143    |
# | val_acc@1_q3   | 0.727    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.709    |
# | val_loss_q0    | 0.701    |
# | val_loss_q1    | 0.739    |
# | val_loss_q2    | 0.861    |
# | val_loss_q3    | 0.608    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 3.87     |
# | param_norm     | 160      |
# | samples        | 1.62e+03 |
# | step           | 100      |
# | train_acc@1    | 0.594    |
# | train_acc@1_q0 | 0.535    |
# | train_acc@1_q1 | 0.585    |
# | train_acc@1_q2 | 0.571    |
# | train_acc@1_q3 | 0.706    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.683    |
# | train_loss_q0  | 0.694    |
# | train_loss_q1  | 0.693    |
# | train_loss_q2  | 0.703    |
# | train_loss_q3  | 0.632    |
# | val_acc@1      | 0.531    |
# | val_acc@1_q0   | 0.4      |
# | val_acc@1_q1   | 0.714    |
# | val_acc@1_q2   | 0.444    |
# | val_acc@1_q3   | 0.667    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.719    |
# | val_loss_q0    | 0.809    |
# | val_loss_q1    | 0.588    |
# | val_loss_q2    | 0.826    |
# | val_loss_q3    | 0.562    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 6.79     |
# | param_norm     | 160      |
# | samples        | 1.78e+03 |
# | step           | 110      |
# | train_acc@1    | 0.494    |
# | train_acc@1_q0 | 0.457    |
# | train_acc@1_q1 | 0.575    |
# | train_acc@1_q2 | 0.476    |
# | train_acc@1_q3 | 0.469    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.701    |
# | train_loss_q0  | 0.726    |
# | train_loss_q1  | 0.652    |
# | train_loss_q2  | 0.702    |
# | train_loss_q3  | 0.724    |
# | val_acc@1      | 0.562    |
# | val_acc@1_q0   | 0.444    |
# | val_acc@1_q1   | 0.7      |
# | val_acc@1_q2   | 0.667    |
# | val_acc@1_q3   | 0.429    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.675    |
# | val_loss_q0    | 0.691    |
# | val_loss_q1    | 0.661    |
# | val_loss_q2    | 0.635    |
# | val_loss_q3    | 0.708    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 7.88     |
# | param_norm     | 160      |
# | samples        | 1.94e+03 |
# | step           | 120      |
# | train_acc@1    | 0.594    |
# | train_acc@1_q0 | 0.667    |
# | train_acc@1_q1 | 0.622    |
# | train_acc@1_q2 | 0.587    |
# | train_acc@1_q3 | 0.5      |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.686    |
# | train_loss_q0  | 0.651    |
# | train_loss_q1  | 0.666    |
# | train_loss_q2  | 0.669    |
# | train_loss_q3  | 0.76     |
# | val_acc@1      | 0.406    |
# | val_acc@1_q0   | 0.3      |
# | val_acc@1_q1   | 0.143    |
# | val_acc@1_q2   | 0.625    |
# | val_acc@1_q3   | 0.571    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.876    |
# | val_loss_q0    | 0.935    |
# | val_loss_q1    | 1.12     |
# | val_loss_q2    | 0.71     |
# | val_loss_q3    | 0.744    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 8.74     |
# | param_norm     | 160      |
# | samples        | 2.1e+03  |
# | step           | 130      |
# | train_acc@1    | 0.469    |
# | train_acc@1_q0 | 0.531    |
# | train_acc@1_q1 | 0.421    |
# | train_acc@1_q2 | 0.574    |
# | train_acc@1_q3 | 0.349    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.706    |
# | train_loss_q0  | 0.674    |
# | train_loss_q1  | 0.713    |
# | train_loss_q2  | 0.683    |
# | train_loss_q3  | 0.748    |
# | val_acc@1      | 0.719    |
# | val_acc@1_q0   | 0.875    |
# | val_acc@1_q1   | 0.625    |
# | val_acc@1_q2   | 0.833    |
# | val_acc@1_q3   | 0.6      |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.599    |
# | val_loss_q0    | 0.524    |
# | val_loss_q1    | 0.63     |
# | val_loss_q2    | 0.576    |
# | val_loss_q3    | 0.649    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 5.42     |
# | param_norm     | 160      |
# | samples        | 2.26e+03 |
# | step           | 140      |
# | train_acc@1    | 0.6      |
# | train_acc@1_q0 | 0.55     |
# | train_acc@1_q1 | 0.625    |
# | train_acc@1_q2 | 0.615    |
# | train_acc@1_q3 | 0.609    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.706    |
# | train_loss_q0  | 0.772    |
# | train_loss_q1  | 0.669    |
# | train_loss_q2  | 0.668    |
# | train_loss_q3  | 0.708    |
# | val_acc@1      | 0.406    |
# | val_acc@1_q0   | 0.455    |
# | val_acc@1_q1   | 0.3      |
# | val_acc@1_q2   | 0.5      |
# | val_acc@1_q3   | 0.429    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.807    |
# | val_loss_q0    | 0.78     |
# | val_loss_q1    | 0.907    |
# | val_loss_q2    | 0.762    |
# | val_loss_q3    | 0.733    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 4.24     |
# | param_norm     | 160      |
# | samples        | 2.42e+03 |
# | step           | 150      |
# | train_acc@1    | 0.631    |
# | train_acc@1_q0 | 0.653    |
# | train_acc@1_q1 | 0.455    |
# | train_acc@1_q2 | 0.683    |
# | train_acc@1_q3 | 0.703    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.664    |
# | train_loss_q0  | 0.654    |
# | train_loss_q1  | 0.706    |
# | train_loss_q2  | 0.639    |
# | train_loss_q3  | 0.669    |
# | val_acc@1      | 0.469    |
# | val_acc@1_q0   | 0.4      |
# | val_acc@1_q1   | 0.625    |
# | val_acc@1_q2   | 0.429    |
# | val_acc@1_q3   | 0.429    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.779    |
# | val_loss_q0    | 0.731    |
# | val_loss_q1    | 0.764    |
# | val_loss_q2    | 0.794    |
# | val_loss_q3    | 0.851    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 7.12     |
# | param_norm     | 160      |
# | samples        | 2.58e+03 |
# | step           | 160      |
# | train_acc@1    | 0.487    |
# | train_acc@1_q0 | 0.512    |
# | train_acc@1_q1 | 0.45     |
# | train_acc@1_q2 | 0.489    |
# | train_acc@1_q3 | 0.5      |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.734    |
# | train_loss_q0  | 0.697    |
# | train_loss_q1  | 0.75     |
# | train_loss_q2  | 0.761    |
# | train_loss_q3  | 0.723    |
# | val_acc@1      | 0.406    |
# | val_acc@1_q0   | 0.545    |
# | val_acc@1_q1   | 0.364    |
# | val_acc@1_q2   | 0.4      |
# | val_acc@1_q3   | 0.2      |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.745    |
# | val_loss_q0    | 0.707    |
# | val_loss_q1    | 0.778    |
# | val_loss_q2    | 0.69     |
# | val_loss_q3    | 0.813    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 8.17     |
# | param_norm     | 160      |
# | samples        | 2.74e+03 |
# | step           | 170      |
# | train_acc@1    | 0.494    |
# | train_acc@1_q0 | 0.4      |
# | train_acc@1_q1 | 0.523    |
# | train_acc@1_q2 | 0.605    |
# | train_acc@1_q3 | 0.447    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.742    |
# | train_loss_q0  | 0.771    |
# | train_loss_q1  | 0.747    |
# | train_loss_q2  | 0.72     |
# | train_loss_q3  | 0.726    |
# | val_acc@1      | 0.562    |
# | val_acc@1_q0   | 0.615    |
# | val_acc@1_q1   | 0.8      |
# | val_acc@1_q2   | 0.375    |
# | val_acc@1_q3   | 0.5      |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.722    |
# | val_loss_q0    | 0.699    |
# | val_loss_q1    | 0.565    |
# | val_loss_q2    | 0.842    |
# | val_loss_q3    | 0.741    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 3.72     |
# | param_norm     | 160      |
# | samples        | 2.9e+03  |
# | step           | 180      |
# | train_acc@1    | 0.525    |
# | train_acc@1_q0 | 0.579    |
# | train_acc@1_q1 | 0.541    |
# | train_acc@1_q2 | 0.523    |
# | train_acc@1_q3 | 0.463    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.695    |
# | train_loss_q0  | 0.674    |
# | train_loss_q1  | 0.7      |
# | train_loss_q2  | 0.693    |
# | train_loss_q3  | 0.711    |
# | val_acc@1      | 0.438    |
# | val_acc@1_q0   | 0.444    |
# | val_acc@1_q1   | 0.5      |
# | val_acc@1_q2   | 0.2      |
# | val_acc@1_q3   | 0.5      |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.715    |
# | val_loss_q0    | 0.697    |
# | val_loss_q1    | 0.737    |
# | val_loss_q2    | 0.735    |
# | val_loss_q3    | 0.704    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 4.88     |
# | param_norm     | 160      |
# | samples        | 3.06e+03 |
# | step           | 190      |
# | train_acc@1    | 0.5      |
# | train_acc@1_q0 | 0.512    |
# | train_acc@1_q1 | 0.5      |
# | train_acc@1_q2 | 0.643    |
# | train_acc@1_q3 | 0.341    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.707    |
# | train_loss_q0  | 0.71     |
# | train_loss_q1  | 0.688    |
# | train_loss_q2  | 0.669    |
# | train_loss_q3  | 0.76     |
# | val_acc@1      | 0.5      |
# | val_acc@1_q0   | 0.5      |
# | val_acc@1_q1   | 0.286    |
# | val_acc@1_q2   | 0.6      |
# | val_acc@1_q3   | 0.571    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.705    |
# | val_loss_q0    | 0.693    |
# | val_loss_q1    | 0.751    |
# | val_loss_q2    | 0.708    |
# | val_loss_q3    | 0.67     |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 7.48     |
# | param_norm     | 160      |
# | samples        | 3.22e+03 |
# | step           | 200      |
# | train_acc@1    | 0.581    |
# | train_acc@1_q0 | 0.463    |
# | train_acc@1_q1 | 0.7      |
# | train_acc@1_q2 | 0.571    |
# | train_acc@1_q3 | 0.588    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.708    |
# | train_loss_q0  | 0.735    |
# | train_loss_q1  | 0.648    |
# | train_loss_q2  | 0.739    |
# | train_loss_q3  | 0.717    |
# | val_acc@1      | 0.344    |
# | val_acc@1_q0   | 0.333    |
# | val_acc@1_q1   | 0.167    |
# | val_acc@1_q2   | 0.333    |
# | val_acc@1_q3   | 0.455    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.779    |
# | val_loss_q0    | 0.771    |
# | val_loss_q1    | 0.827    |
# | val_loss_q2    | 0.808    |
# | val_loss_q3    | 0.733    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 6.56     |
# | param_norm     | 160      |
# | samples        | 3.38e+03 |
# | step           | 210      |
# | train_acc@1    | 0.487    |
# | train_acc@1_q0 | 0.436    |
# | train_acc@1_q1 | 0.487    |
# | train_acc@1_q2 | 0.625    |
# | train_acc@1_q3 | 0.405    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.713    |
# | train_loss_q0  | 0.714    |
# | train_loss_q1  | 0.714    |
# | train_loss_q2  | 0.681    |
# | train_loss_q3  | 0.743    |
# | val_acc@1      | 0.438    |
# | val_acc@1_q0   | 0.167    |
# | val_acc@1_q1   | 0.429    |
# | val_acc@1_q2   | 0.417    |
# | val_acc@1_q3   | 0.714    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.722    |
# | val_loss_q0    | 0.763    |
# | val_loss_q1    | 0.694    |
# | val_loss_q2    | 0.735    |
# | val_loss_q3    | 0.692    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 4.53     |
# | param_norm     | 160      |
# | samples        | 3.54e+03 |
# | step           | 220      |
# | train_acc@1    | 0.594    |
# | train_acc@1_q0 | 0.649    |
# | train_acc@1_q1 | 0.531    |
# | train_acc@1_q2 | 0.667    |
# | train_acc@1_q3 | 0.561    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.687    |
# | train_loss_q0  | 0.615    |
# | train_loss_q1  | 0.746    |
# | train_loss_q2  | 0.682    |
# | train_loss_q3  | 0.687    |
# | val_acc@1      | 0.5      |
# | val_acc@1_q0   | 0.778    |
# | val_acc@1_q1   | 0.444    |
# | val_acc@1_q2   | 0.286    |
# | val_acc@1_q3   | 0.429    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.763    |
# | val_loss_q0    | 0.526    |
# | val_loss_q1    | 0.809    |
# | val_loss_q2    | 0.952    |
# | val_loss_q3    | 0.818    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 6.12     |
# | param_norm     | 160      |
# | samples        | 3.7e+03  |
# | step           | 230      |
# | train_acc@1    | 0.487    |
# | train_acc@1_q0 | 0.415    |
# | train_acc@1_q1 | 0.353    |
# | train_acc@1_q2 | 0.551    |
# | train_acc@1_q3 | 0.611    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.69     |
# | train_loss_q0  | 0.727    |
# | train_loss_q1  | 0.757    |
# | train_loss_q2  | 0.655    |
# | train_loss_q3  | 0.634    |
# | val_acc@1      | 0.469    |
# | val_acc@1_q0   | 0.6      |
# | val_acc@1_q1   | 0.375    |
# | val_acc@1_q2   | 0.5      |
# | val_acc@1_q3   | 0.333    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.703    |
# | val_loss_q0    | 0.677    |
# | val_loss_q1    | 0.726    |
# | val_loss_q2    | 0.688    |
# | val_loss_q3    | 0.734    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 7.67     |
# | param_norm     | 160      |
# | samples        | 3.86e+03 |
# | step           | 240      |
# | train_acc@1    | 0.55     |
# | train_acc@1_q0 | 0.35     |
# | train_acc@1_q1 | 0.696    |
# | train_acc@1_q2 | 0.535    |
# | train_acc@1_q3 | 0.613    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.727    |
# | train_loss_q0  | 0.846    |
# | train_loss_q1  | 0.617    |
# | train_loss_q2  | 0.776    |
# | train_loss_q3  | 0.671    |
# | val_acc@1      | 0.531    |
# | val_acc@1_q0   | 0.5      |
# | val_acc@1_q1   | 0.143    |
# | val_acc@1_q2   | 0.7      |
# | val_acc@1_q3   | 0.714    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.751    |
# | val_loss_q0    | 0.771    |
# | val_loss_q1    | 1.13     |
# | val_loss_q2    | 0.598    |
# | val_loss_q3    | 0.572    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 6        |
# | param_norm     | 160      |
# | samples        | 4.02e+03 |
# | step           | 250      |
# | train_acc@1    | 0.431    |
# | train_acc@1_q0 | 0.562    |
# | train_acc@1_q1 | 0.465    |
# | train_acc@1_q2 | 0.289    |
# | train_acc@1_q3 | 0.426    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.714    |
# | train_loss_q0  | 0.678    |
# | train_loss_q1  | 0.705    |
# | train_loss_q2  | 0.746    |
# | train_loss_q3  | 0.723    |
# | val_acc@1      | 0.438    |
# | val_acc@1_q0   | 0.5      |
# | val_acc@1_q1   | 0.2      |
# | val_acc@1_q2   | 0.667    |
# | val_acc@1_q3   | 0.556    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.72     |
# | val_loss_q0    | 0.713    |
# | val_loss_q1    | 0.751    |
# | val_loss_q2    | 0.613    |
# | val_loss_q3    | 0.728    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 6.66     |
# | param_norm     | 160      |
# | samples        | 4.18e+03 |
# | step           | 260      |
# | train_acc@1    | 0.575    |
# | train_acc@1_q0 | 0.517    |
# | train_acc@1_q1 | 0.489    |
# | train_acc@1_q2 | 0.6      |
# | train_acc@1_q3 | 0.673    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.701    |
# | train_loss_q0  | 0.706    |
# | train_loss_q1  | 0.763    |
# | train_loss_q2  | 0.691    |
# | train_loss_q3  | 0.644    |
# | val_acc@1      | 0.5      |
# | val_acc@1_q0   | 0.8      |
# | val_acc@1_q1   | 0.333    |
# | val_acc@1_q2   | 0.625    |
# | val_acc@1_q3   | 0.4      |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.752    |
# | val_loss_q0    | 0.553    |
# | val_loss_q1    | 0.881    |
# | val_loss_q2    | 0.665    |
# | val_loss_q3    | 0.804    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 6.92     |
# | param_norm     | 160      |
# | samples        | 4.34e+03 |
# | step           | 270      |
# | train_acc@1    | 0.575    |
# | train_acc@1_q0 | 0.632    |
# | train_acc@1_q1 | 0.426    |
# | train_acc@1_q2 | 0.63     |
# | train_acc@1_q3 | 0.655    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.686    |
# | train_loss_q0  | 0.657    |
# | train_loss_q1  | 0.726    |
# | train_loss_q2  | 0.671    |
# | train_loss_q3  | 0.679    |
# | val_acc@1      | 0.594    |
# | val_acc@1_q0   | 0.714    |
# | val_acc@1_q1   | 0.6      |
# | val_acc@1_q2   | 0.556    |
# | val_acc@1_q3   | 0.545    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.72     |
# | val_loss_q0    | 0.662    |
# | val_loss_q1    | 0.587    |
# | val_loss_q2    | 0.754    |
# | val_loss_q3    | 0.789    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 6.11     |
# | param_norm     | 160      |
# | samples        | 4.5e+03  |
# | step           | 280      |
# | train_acc@1    | 0.612    |
# | train_acc@1_q0 | 0.703    |
# | train_acc@1_q1 | 0.564    |
# | train_acc@1_q2 | 0.548    |
# | train_acc@1_q3 | 0.643    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.676    |
# | train_loss_q0  | 0.586    |
# | train_loss_q1  | 0.708    |
# | train_loss_q2  | 0.737    |
# | train_loss_q3  | 0.667    |
# | val_acc@1      | 0.438    |
# | val_acc@1_q0   | 0.5      |
# | val_acc@1_q1   | 0.571    |
# | val_acc@1_q2   | 0.3      |
# | val_acc@1_q3   | 0.429    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.827    |
# | val_loss_q0    | 0.813    |
# | val_loss_q1    | 0.722    |
# | val_loss_q2    | 0.912    |
# | val_loss_q3    | 0.829    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 4.93     |
# | param_norm     | 160      |
# | samples        | 4.66e+03 |
# | step           | 290      |
# | train_acc@1    | 0.594    |
# | train_acc@1_q0 | 0.556    |
# | train_acc@1_q1 | 0.61     |
# | train_acc@1_q2 | 0.634    |
# | train_acc@1_q3 | 0.571    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.689    |
# | train_loss_q0  | 0.689    |
# | train_loss_q1  | 0.695    |
# | train_loss_q2  | 0.691    |
# | train_loss_q3  | 0.682    |
# | val_acc@1      | 0.719    |
# | val_acc@1_q0   | 0.818    |
# | val_acc@1_q1   | 0.833    |
# | val_acc@1_q2   | 0.556    |
# | val_acc@1_q3   | 0.667    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.657    |
# | val_loss_q0    | 0.656    |
# | val_loss_q1    | 0.633    |
# | val_loss_q2    | 0.636    |
# | val_loss_q3    | 0.713    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 7.76     |
# | param_norm     | 160      |
# | samples        | 4.82e+03 |
# | step           | 300      |
# | train_acc@1    | 0.669    |
# | train_acc@1_q0 | 0.74     |
# | train_acc@1_q1 | 0.683    |
# | train_acc@1_q2 | 0.576    |
# | train_acc@1_q3 | 0.639    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.671    |
# | train_loss_q0  | 0.604    |
# | train_loss_q1  | 0.669    |
# | train_loss_q2  | 0.756    |
# | train_loss_q3  | 0.689    |
# | val_acc@1      | 0.656    |
# | val_acc@1_q0   | 0.778    |
# | val_acc@1_q1   | 0.7      |
# | val_acc@1_q2   | 0.333    |
# | val_acc@1_q3   | 0.714    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.668    |
# | val_loss_q0    | 0.545    |
# | val_loss_q1    | 0.591    |
# | val_loss_q2    | 0.978    |
# | val_loss_q3    | 0.671    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# -----------------------------
# | grad_norm      | 5.76     |
# | param_norm     | 160      |
# | samples        | 4.98e+03 |
# | step           | 310      |
# | train_acc@1    | 0.606    |
# | train_acc@1_q0 | 0.633    |
# | train_acc@1_q1 | 0.636    |
# | train_acc@1_q2 | 0.448    |
# | train_acc@1_q3 | 0.658    |
# | train_acc@5    | 1        |
# | train_acc@5_q0 | 1        |
# | train_acc@5_q1 | 1        |
# | train_acc@5_q2 | 1        |
# | train_acc@5_q3 | 1        |
# | train_loss     | 0.69     |
# | train_loss_q0  | 0.651    |
# | train_loss_q1  | 0.697    |
# | train_loss_q2  | 0.775    |
# | train_loss_q3  | 0.667    |
# | val_acc@1      | 0.656    |
# | val_acc@1_q0   | 0.889    |
# | val_acc@1_q1   | 0.714    |
# | val_acc@1_q2   | 0.6      |
# | val_acc@1_q3   | 0.333    |
# | val_acc@5      | 1        |
# | val_acc@5_q0   | 1        |
# | val_acc@5_q1   | 1        |
# | val_acc@5_q2   | 1        |
# | val_acc@5_q3   | 1        |
# | val_loss       | 0.674    |
# | val_loss_q0    | 0.665    |
# | val_loss_q1    | 0.643    |
# | val_loss_q2    | 0.695    |
# | val_loss_q3    | 0.689    |
# -----------------------------
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# saving model...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\anaconda3\envs\en_2\lib\site-packages\torch\serialization.py:436, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     435 with _open_zipfile_writer(f) as opened_zipfile:
# --> 436     _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     437     return
#
# File ~\anaconda3\envs\en_2\lib\site-packages\torch\serialization.py:663, in _save(obj, zip_file, pickle_module, pickle_protocol)
#     662 num_bytes = storage.nbytes()
# --> 663 zip_file.write_record(name, storage.data_ptr(), num_bytes)
#
# RuntimeError: [enforce fail at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\caffe2\serialize\inline_container.cc:464] . PytorchStreamWriter failed writing file data/481: file write failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 183
#     179     return parser
#     182 if __name__ == "__main__":
# --> 183     main()
#
# Cell In[9], line 120, in main()
#     118         if (step + resume_step) % args.save_interval:
#     119             logger.log("saving model...")
# --> 120             save_model(mp_trainer, opt, step + resume_step)
#     122 #     if dist.get_rank() == 0:
#     123     logger.log("saving model...")
#
# Cell In[9], line 139, in save_model(mp_trainer, opt, step)
#     134 def save_model(mp_trainer, opt, step):
#     135     th.save(
#     136         mp_trainer.master_params_to_state_dict(mp_trainer.master_params),
#     137         os.path.join(logger.get_dir(), f"model{step:06d}.pt"),
#     138     )
# --> 139     th.save(opt.state_dict(), os.path.join(logger.get_dir(), f"opt{step:06d}.pt"))
#
# File ~\anaconda3\envs\en_2\lib\site-packages\torch\serialization.py:437, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     435     with _open_zipfile_writer(f) as opened_zipfile:
#     436         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
# --> 437         return
#     438 else:
#     439     with _open_file_like(f, 'wb') as opened_file:
#
# File ~\anaconda3\envs\en_2\lib\site-packages\torch\serialization.py:290, in _open_zipfile_writer_file.__exit__(self, *args)
#     289 def __exit__(self, *args) -> None:
# --> 290     self.file_like.write_end_of_file()
#
# RuntimeError: [enforce fail at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\caffe2\serialize\inline_container.cc:325] . unexpected pos 128958528 vs 128958420
